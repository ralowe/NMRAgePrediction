# %% [markdown]
# ## Example
# The following notebook leads you through how to run the clock on a CSV file containing methylation values.
#
# The first step is to load the clock functions using the following import function

# %%
import run_clock

# %% [markdown]
# Then to actually run the clock we just need to supply a path and filename of the CSV file

# %%
results = run_clock.run_clock("test_data/test_data.csv")

# %%
import pandas as pd
pd.DataFrame(results, index=["Sample ID","Predicted age in weeks"]).T
# Out:
#    Sample ID Predicted age in weeks
# 0         A3      47.87228904505929
# 1         A4      67.74280883199435
# 2        B10      35.06786750185323
# 3         A8     255.43529963604936
# 4         D5     18.171317308751156
# 5        A10     210.37594646128636
# 6         B2     132.11151742844595
# 7         D1      395.4040311598618
# 8        C12      294.6632328177122
# 9         D7      515.8264680309857
# 10        C9      366.8095299025948
# 11       A12      63.09486725016385
# 12        A5     332.54075892351204
# 13        B4      637.3633045045741
# 14        C1      389.6712576074243
# 15        B3      679.0136107007705
# 16        C8      37.43794637496039
# 17        B5     1000.2142419943636
# 18       D12      464.1087742294861
# 19        A9      448.3424244407431
# 20        D9     504.69869319617044
# 21        B1     370.32870799963854
# 22        D8     188.47014674532792
# 23        A7     162.76791448439383
# 24        B6      571.0900610625725
# ...
